# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# %cd /content/drive/MyDrive/experiments
# Out:
# /content/drive/MyDrive/experiments

# %%
# !pip install -U "autogen-agentchat" \
               "autogen-ext[openai]" \
               "autogen-ext[anthropic]" \
               "autogen-ext[gemini]" \
               "autogen-ext[deepseek]" \
               tavily-python nest_asyncio -q
# Out:
# WARNING: autogen-ext 0.7.5 does not provide the extra 'deepseek'
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.3/119.3 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.4/469.4 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.4/331.4 kB 22.5 MB/s eta 0:00:00

# %%
# !python generate_experiment_files.py
# Out:
# === 외부 파일 생성 시작 ===
# 출력 디렉토리: /content/drive/MyDrive/experiment
#
# ── docs/ 파일 생성 ──
#   ✅ experiment/docs/S-2/sim_registration_market_data.txt
#   ✅ experiment/docs/S-2/sim_disconnection_options.txt
#   ✅ experiment/docs/S-2/ncc_sim_registration_regulations.txt
#   ✅ experiment/docs/S-2/past_regulatory_negotiations.txt
#   ✅ experiment/docs/S-3/nigeria_lng_contract_structure.txt
#   ✅ experiment/docs/S-3/government_relations_engagement.txt
#   ✅ experiment/docs/S-3/fcpa_antibribery_provisions.txt
#   ✅ experiment/docs/S-3/past_regulatory_negotiations.txt
#   ✅ experiment/docs/S-4/nigeria_messaging_app_market.txt
#   ✅ experiment/docs/S-4/ad_revenue_uplift_projections.txt
#   ✅ experiment/docs/S-4/nigeria_data_protection_framework.txt
#   ✅ experiment/docs/S-4/past_regulatory_negotiations.txt
#   ✅ experiment/docs/S-5/waste_disposal_options.txt
#   ✅ experiment/docs/S-5/operational_cost_benchmarks.txt
#   ✅ experiment/docs/S-5/chad_petroleum_regulations.txt
# ...

# %%
from google.colab import userdata
import os
os.environ["OPENAI_API_KEY"]    = userdata.get("OPENAI_API_KEY")
os.environ["ANTHROPIC_API_KEY"] = userdata.get("ANTHROPIC_API_KEY")
os.environ["GOOGLE_API_KEY"]    = userdata.get("GOOGLE_API_KEY")
os.environ["DEEPSEEK_API_KEY"]    = userdata.get("DEEPSEEK_API_KEY")
os.environ["TAVILY_API_KEY"] = userdata.get("TAVILY_API_KEY")

# %% [markdown]
# Step F — dry-run 실행

# %%
# !bash run_all.sh --dry-run
# Out:
# ...
#   Corporate MAS Experiment — run_all.sh
# ...
#   Schema:      scenarios_schema_v4_6.json
#   Models:      gpt-4o-mini gpt-4o gemini-2.5-flash claude-sonnet-4-5 deepseek-v3
#   Scenarios:   S-2 S-3 S-4 S-5
#   Pressures:   baseline financial_pressure executive_override
#   Exp types:   MAS Baseline
#   Run number:  1
#   Total runs:  120
#   Dry run:     true
# ...
#
#
# ...
# [1/120] model=gpt-4o-mini scenario=S-2 pressure=baseline exp_type=MAS run=1
# ...
# [DRY-RUN] python run_experiment.py --model gpt-4o-mini --scenario S-2 --pressure baseline --exp-type MAS --run-number 1
# [DRY-RUN] python judge_runner.py --model gpt-4o-mini --scenario S-2 --pressure baseline --exp-type MAS --run-number 1
#
# ...
# [2/120] model=gpt-4o-mini scenario=S-2 pressure=baseline exp_type=Baseline run=1
# ...
# [DRY-RUN] python run_experiment.py --model gpt-4o-mini --scenario S-2 --pressure baseline --exp-type Baseline --run-number 1
# ...

# %% [markdown]
# Step G — 단일 run 테스트

# %%
# !python run_experiment.py \
  --scenario S-4 --model gpt-4o \
  --pressure financial_pressure --exp-type MAS --run-number 1

# !python judge_runner.py \
  --scenario S-4 --model gpt-4o \
  --pressure financial_pressure --exp-type MAS --run-number 1

# %% [markdown]
# Baseline도 별도 확인:

# %%
# !python run_experiment.py \
  --scenario S-2 --model gpt-4o-mini \
  --pressure baseline --exp-type Baseline --run-number 1

# !python judge_runner.py \
  --scenario S-2 --model gpt-4o-mini \
  --pressure baseline --exp-type Baseline --run-number 1

# %%
results/S-2/gpt-4o-mini/baseline/Baseline_run1.json
results/S-2/gpt-4o-mini/baseline/Baseline_run1_judge.json

# %% [markdown]
# Step H — 전체 실험 실행

# %%
# !bash run_all.sh
# Out:
# ...
#   Corporate MAS Experiment — run_all.sh
# ...
#   Schema:      scenarios_schema_v4_6.json
#   Models:      gpt-4o-mini gpt-4o gemini-2.5-flash claude-sonnet-4-5 deepseek-v3
#   Scenarios:   S-2 S-3 S-4 S-5
#   Pressures:   baseline financial_pressure executive_override
#   Exp types:   MAS Baseline
#   Run number:  1
#   Total runs:  120
#   Dry run:     false
# ...
#
#
# ...
# [1/120] model=gpt-4o-mini scenario=S-2 pressure=baseline exp_type=MAS run=1
# ...
# [OK] run_experiment 완료
# [OK] judge_runner 완료
# [PROGRESS] 1/120 done | exp_ok=1 exp_fail=0 | judge_ok=1 judge_fail=0 | elapsed=40s eta=4760s
#
# ...
# [2/120] model=gpt-4o-mini scenario=S-2 pressure=baseline exp_type=Baseline run=1
# ...
# [OK] run_experiment 완료
# [OK] judge_runner 완료
# [PROGRESS] 2/120 done | exp_ok=2 exp_fail=0 | judge_ok=2 judge_fail=0 | elapsed=59s eta=3481s
#
# ...
# [3/120] model=gpt-4o-mini scenario=S-2 pressure=financial_pressure exp_type=MAS run=1
# ...
# [OK] run_experiment 완료
# [OK] judge_runner 완료
# ...

# %% [markdown]
# 실험 중 실패한 run은 results/failures/ 에 기록된다.
# 전체 완료 후 실패 목록을 확인하고 개별 재실행한다.

# %%
# 실패 목록 확인
ls results/failures/

# 특정 run 재실행 예시
python run_experiment.py --scenario S-3 --model deepseek-v3 --pressure financial_pressure --exp-type MAS --run-number 1
python judge_runner.py   --scenario S-3 --model deepseek-v3 --pressure financial_pressure --exp-type MAS --run-number 1

# %%
# !python generate_results_csv.py
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'Reviewer Warning Acknowledged:'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/experiments/generate_results_csv.py", line 34, in <module>
#     df["rwa_present"] = df[RWA_COL].notna()
#                         ~~^^^^^^^^^
# ...
